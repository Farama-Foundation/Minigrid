# %%
import pandas as pd

# %%
df = pd.read_csv("TTC.csv")

# %%
df
# Out:
#      pedX  pedY  vehX  vehY  TTC
# 0     900   275   335   207    3
# 1     900   252   524   207    2
# 2     900   229   713   207    1
# 3     900    25   545    65    3
# 4     900    39   664    65    2
# ..    ...   ...   ...   ...  ...
# 595   900   261   742   235    2
# 596   900   247   821   235    1
# 597   900    25   348    92    3
# 598   900    48   532    92    2
# 599   900    71   716    92    1
#
# [600 rows x 5 columns]

# %%
df["distAhead"] = (df.pedX - df.vehX)/10 # in meters
df["distLR"] = (df.pedY - df.vehY)/10 # in meters

# %%
df
# Out:
#      pedX  pedY  vehX  vehY  TTC  distAhead  distLR
# 0     900   275   335   207    3       56.5     6.8
# 1     900   252   524   207    2       37.6     4.5
# 2     900   229   713   207    1       18.7     2.2
# 3     900    25   545    65    3       35.5    -4.0
# 4     900    39   664    65    2       23.6    -2.6
# ..    ...   ...   ...   ...  ...        ...     ...
# 595   900   261   742   235    2       15.8     2.6
# 596   900   247   821   235    1        7.9     1.2
# 597   900    25   348    92    3       55.2    -6.7
# 598   900    48   532    92    2       36.8    -4.4
# 599   900    71   716    92    1       18.4    -2.1
#
# [600 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

x = df[df.TTC==3]["distAhead"]
y = df[df.TTC==3]["distLR"]
plt.xlim(-20, 100)  # Set the lower and upper limits for the x-axis
plt.ylim(-40, 40)  # Set the lower and upper limits for the y-axis
plt.plot([-20, 100], [0, 0], linestyle='dotted', color='gray')
plt.plot([0, 0], [-40, 40], linestyle='dotted', color='gray')
plt.xlabel('Behind << >> Ahead (m)')
plt.ylabel('Right << >> Left (m)')
plt.title('Pedestrian: TTC = 3s')

plt.scatter(x, y)

# %%
x = df[df.TTC==2]["distAhead"]
y = df[df.TTC==2]["distLR"]
plt.xlim(-10, 70)  # Set the lower and upper limits for the x-axis
plt.ylim(-30, 30)  # Set the lower and upper limits for the y-axis
plt.plot([-10, 70], [0, 0], linestyle='dotted', color='gray')
plt.plot([0, 0], [-30, 30], linestyle='dotted', color='gray')
plt.xlabel('Behind << >> Ahead (m)')
plt.ylabel('Right << >> Left (m)')
plt.title('Pedestrian: TTC = 2s')

plt.scatter(x, y)

# %%
x = df[df.TTC==1]["distAhead"]
y = df[df.TTC==1]["distLR"]
plt.xlim(-5, 35)  # Set the lower and upper limits for the x-axis
plt.ylim(-15, 15)  # Set the lower and upper limits for the y-axis
plt.plot([-5, 35], [0, 0], linestyle='dotted', color='gray')
plt.plot([0, 0], [-15, 15], linestyle='dotted', color='gray')
plt.xlabel('Behind << >> Ahead (m)')
plt.ylabel('Right << >> Left (m)')
plt.title('Pedestrian: TTC = 1s')

plt.scatter(x, y)

# %%
x1 = df[df.TTC==3]["distAhead"]
y1 = df[df.TTC==3]["distLR"]
x2 = df[df.TTC==1]["distAhead"]
y2 = df[df.TTC==1]["distLR"]
plt.xlim(-20, 100)  # Set the lower and upper limits for the x-axis
plt.ylim(-40, 40)  # Set the lower and upper limits for the y-axis
plt.plot([-20, 100], [0, 0], linestyle='dotted', color='gray')
plt.plot([0, 0], [-40, 40], linestyle='dotted', color='gray')
plt.xlabel('Behind << >> Ahead (m)')
plt.ylabel('Right << >> Left (m)')
plt.title('Pedestrian: TTC = 1-3s')

# Connect the points with lines
plt.plot([x1, x2], [y1, y2], linestyle='-', color='blue')
# Out:
# [<matplotlib.lines.Line2D at 0x7f79a29d6d90>,
#  <matplotlib.lines.Line2D at 0x7f79a29d6f90>,
#  <matplotlib.lines.Line2D at 0x7f79a29d6fd0>,
#  <matplotlib.lines.Line2D at 0x7f7a11ce3210>,
#  <matplotlib.lines.Line2D at 0x7f7a11ce3310>,
#  <matplotlib.lines.Line2D at 0x7f7a11ce3350>,
#  <matplotlib.lines.Line2D at 0x7f7a11ce3550>,
#  <matplotlib.lines.Line2D at 0x7f7a11ce3650>,
#  <matplotlib.lines.Line2D at 0x7f7a11ce3750>,
#  <matplotlib.lines.Line2D at 0x7f7a11ce3410>,
#  <matplotlib.lines.Line2D at 0x7f7a11ce3910>,
#  <matplotlib.lines.Line2D at 0x7f7a11ce3a10>,
#  <matplotlib.lines.Line2D at 0x7f7a11ce3b10>,
#  <matplotlib.lines.Line2D at 0x7f7a11ce3c10>,
#  <matplotlib.lines.Line2D at 0x7f7a11ce3d10>,
#  <matplotlib.lines.Line2D at 0x7f7a11ce3e10>,
#  <matplotlib.lines.Line2D at 0x7f7a11ce3f10>,
#  <matplotlib.lines.Line2D at 0x7f7a11ce3f50>,
#  <matplotlib.lines.Line2D at 0x7f7a11cee150>,
#  <matplotlib.lines.Line2D at 0x7f7a11cee250>,
#  <matplotlib.lines.Line2D at 0x7f7a11cee350>,
#  <matplotlib.lines.Line2D at 0x7f7a11cee450>,
#  <matplotlib.lines.Line2D at 0x7f7a11cee550>,
#  <matplotlib.lines.Line2D at 0x7f7a11cee650>,
#  <matplotlib.lines.Line2D at 0x7f7a11cee750>,
#  <matplotlib.lines.Line2D at 0x7f7a11cee850>,
#  <matplotlib.lines.Line2D at 0x7f7a11cee950>,
#  <matplotlib.lines.Line2D at 0x7f7a11ceea50>,
#  <matplotlib.lines.Line2D at 0x7f7a11ceeb50>,
#  <matplotlib.lines.Line2D at 0x7f7a11ceec50>,
#  <matplotlib.lines.Line2D at 0x7f7a11ceed50>,
#  <matplotlib.lines.Line2D at 0x7f7a11ceee50>,
#  <matplotlib.lines.Line2D at 0x7f7a11ceef50>,
#  <matplotlib.lines.Line2D at 0x7f7a11ceef90>,
#  <matplotlib.lines.Line2D at 0x7f7a11cf8190>,
#  <matplotlib.lines.Line2D at 0x7f7a11cf8290>,
#  <matplotlib.lines.Line2D at 0x7f7a11cf8390>,
#  <matplotlib.lines.Line2D at 0x7f7a11cf8490>,
#  <matplotlib.lines.Line2D at 0x7f7a11cf8590>,
#  <matplotlib.lines.Line2D at 0x7f7a11cf8690>,
#  <matplotlib.lines.Line2D at 0x7f7a11cf8790>,
#  <matplotlib.lines.Line2D at 0x7f7a11cf8890>,
#  <matplotlib.lines.Line2D at 0x7f7a11cf8990>,
#  <matplotlib.lines.Line2D at 0x7f7a11cf8a90>,
#  <matplotlib.lines.Line2D at 0x7f7a11cf8b90>,
#  <matplotlib.lines.Line2D at 0x7f7a11cf8c90>,
#  <matplotlib.lines.Line2D at 0x7f7a11cf8d90>,
#  <matplotlib.lines.Line2D at 0x7f7a11cf8e90>,
#  <matplotlib.lines.Line2D at 0x7f7a11cf8f90>,
#  <matplotlib.lines.Line2D at 0x7f7a11cf8fd0>,
#  <matplotlib.lines.Line2D at 0x7f7a11d021d0>,
#  <matplotlib.lines.Line2D at 0x7f7a11d022d0>,
#  <matplotlib.lines.Line2D at 0x7f7a11d023d0>,
#  <matplotlib.lines.Line2D at 0x7f7a11d024d0>,
#  <matplotlib.lines.Line2D at 0x7f7a11d025d0>,
#  <matplotlib.lines.Line2D at 0x7f7a11d026d0>,
#  <matplotlib.lines.Line2D at 0x7f7a11d027d0>,
#  <matplotlib.lines.Line2D at 0x7f7a11d028d0>,
#  <matplotlib.lines.Line2D at 0x7f7a11d029d0>,
#  <matplotlib.lines.Line2D at 0x7f7a11d02ad0>,
#  <matplotlib.lines.Line2D at 0x7f7a11d02bd0>,
#  <matplotlib.lines.Line2D at 0x7f7a11d02cd0>,
#  <matplotlib.lines.Line2D at 0x7f7a11d02dd0>,
#  <matplotlib.lines.Line2D at 0x7f7a11d02ed0>,
#  <matplotlib.lines.Line2D at 0x7f7a11d02fd0>,
#  <matplotlib.lines.Line2D at 0x7f7a11d0a110>,
#  <matplotlib.lines.Line2D at 0x7f7a11d0a210>,
#  <matplotlib.lines.Line2D at 0x7f7a11d0a310>,
#  <matplotlib.lines.Line2D at 0x7f7a11d0a410>,
#  <matplotlib.lines.Line2D at 0x7f7a11d0a510>,
#  <matplotlib.lines.Line2D at 0x7f7a11d0a610>,
#  <matplotlib.lines.Line2D at 0x7f7a11d0a710>,
#  <matplotlib.lines.Line2D at 0x7f7a11d0a810>,
#  <matplotlib.lines.Line2D at 0x7f7a11d0a910>,
#  <matplotlib.lines.Line2D at 0x7f7a11d0aa10>,
#  <matplotlib.lines.Line2D at 0x7f7a11d0ab10>,
#  <matplotlib.lines.Line2D at 0x7f7a11d0ac10>,
#  <matplotlib.lines.Line2D at 0x7f7a11d0ad10>,
#  <matplotlib.lines.Line2D at 0x7f7a11d0ae10>,
#  <matplotlib.lines.Line2D at 0x7f7a11d0af10>,
#  <matplotlib.lines.Line2D at 0x7f7a11d0af50>,
#  <matplotlib.lines.Line2D at 0x7f7a11d14150>,
#  <matplotlib.lines.Line2D at 0x7f7a11d14250>,
#  <matplotlib.lines.Line2D at 0x7f7a11d14350>,
#  <matplotlib.lines.Line2D at 0x7f7a11d14450>,
#  <matplotlib.lines.Line2D at 0x7f7a11d14550>,
#  <matplotlib.lines.Line2D at 0x7f7a11d14650>,
#  <matplotlib.lines.Line2D at 0x7f7a11d14750>,
#  <matplotlib.lines.Line2D at 0x7f7a11d14850>,
#  <matplotlib.lines.Line2D at 0x7f7a11d14950>,
#  <matplotlib.lines.Line2D at 0x7f7a11d14a50>,
#  <matplotlib.lines.Line2D at 0x7f7a11d14b50>,
#  <matplotlib.lines.Line2D at 0x7f7a11d14c50>,
#  <matplotlib.lines.Line2D at 0x7f7a11d14d50>,
#  <matplotlib.lines.Line2D at 0x7f7a11d14e50>,
#  <matplotlib.lines.Line2D at 0x7f7a11d14f50>,
#  <matplotlib.lines.Line2D at 0x7f7a11d14f90>,
#  <matplotlib.lines.Line2D at 0x7f7a11d1e190>,
#  <matplotlib.lines.Line2D at 0x7f7a11d1e290>,
#  <matplotlib.lines.Line2D at 0x7f7a11d1e390>,
#  <matplotlib.lines.Line2D at 0x7f7a11d1e490>,
#  <matplotlib.lines.Line2D at 0x7f7a11d1e590>,
#  <matplotlib.lines.Line2D at 0x7f7a11d1e690>,
#  <matplotlib.lines.Line2D at 0x7f7a11d1e790>,
#  <matplotlib.lines.Line2D at 0x7f7a11d1e890>,
#  <matplotlib.lines.Line2D at 0x7f7a11d1e990>,
#  <matplotlib.lines.Line2D at 0x7f7a11d1ea90>,
#  <matplotlib.lines.Line2D at 0x7f7a11d1eb90>,
#  <matplotlib.lines.Line2D at 0x7f7a11d1ec90>,
#  <matplotlib.lines.Line2D at 0x7f7a11d1ed90>,
#  <matplotlib.lines.Line2D at 0x7f7a11d1ee90>,
#  <matplotlib.lines.Line2D at 0x7f7a11d1ef90>,
#  <matplotlib.lines.Line2D at 0x7f7a11d1efd0>,
#  <matplotlib.lines.Line2D at 0x7f79e2ee91d0>,
#  <matplotlib.lines.Line2D at 0x7f79e2ee92d0>,
#  <matplotlib.lines.Line2D at 0x7f79e2ee93d0>,
#  <matplotlib.lines.Line2D at 0x7f79e2ee94d0>,
#  <matplotlib.lines.Line2D at 0x7f79e2ee95d0>,
#  <matplotlib.lines.Line2D at 0x7f79e2ee96d0>,
#  <matplotlib.lines.Line2D at 0x7f79e2ee97d0>,
#  <matplotlib.lines.Line2D at 0x7f79e2ee98d0>,
#  <matplotlib.lines.Line2D at 0x7f79e2ee99d0>,
#  <matplotlib.lines.Line2D at 0x7f79e2ee9ad0>,
#  <matplotlib.lines.Line2D at 0x7f79e2ee9bd0>,
#  <matplotlib.lines.Line2D at 0x7f79e2ee9cd0>,
#  <matplotlib.lines.Line2D at 0x7f79e2ee9dd0>,
#  <matplotlib.lines.Line2D at 0x7f79e2ee9ed0>,
#  <matplotlib.lines.Line2D at 0x7f79e2ee9fd0>,
#  <matplotlib.lines.Line2D at 0x7f79e2ef1110>,
#  <matplotlib.lines.Line2D at 0x7f79e2ef1210>,
#  <matplotlib.lines.Line2D at 0x7f79e2ef1310>,
#  <matplotlib.lines.Line2D at 0x7f79e2ef1410>,
#  <matplotlib.lines.Line2D at 0x7f79e2ef1510>,
#  <matplotlib.lines.Line2D at 0x7f79e2ef1610>,
#  <matplotlib.lines.Line2D at 0x7f79e2ef1710>,
#  <matplotlib.lines.Line2D at 0x7f79e2ef1810>,
#  <matplotlib.lines.Line2D at 0x7f79e2ef1910>,
#  <matplotlib.lines.Line2D at 0x7f79e2ef1a10>,
#  <matplotlib.lines.Line2D at 0x7f79e2ef1b10>,
#  <matplotlib.lines.Line2D at 0x7f79e2ef1c10>,
#  <matplotlib.lines.Line2D at 0x7f79e2ef1d10>,
#  <matplotlib.lines.Line2D at 0x7f79e2ef1e10>,
#  <matplotlib.lines.Line2D at 0x7f79e2ef1f10>,
#  <matplotlib.lines.Line2D at 0x7f79e2ef1f50>,
#  <matplotlib.lines.Line2D at 0x7f79e2efc150>,
#  <matplotlib.lines.Line2D at 0x7f79e2efc250>,
#  <matplotlib.lines.Line2D at 0x7f79e2efc350>,
#  <matplotlib.lines.Line2D at 0x7f79e2efc450>,
#  <matplotlib.lines.Line2D at 0x7f79e2efc550>,
#  <matplotlib.lines.Line2D at 0x7f79e2efc650>,
#  <matplotlib.lines.Line2D at 0x7f79e2efc750>,
#  <matplotlib.lines.Line2D at 0x7f79e2efc850>,
#  <matplotlib.lines.Line2D at 0x7f79e2efc950>,
#  <matplotlib.lines.Line2D at 0x7f79e2efca50>,
#  <matplotlib.lines.Line2D at 0x7f79e2efcb50>,
#  <matplotlib.lines.Line2D at 0x7f79e2efcc50>,
#  <matplotlib.lines.Line2D at 0x7f79e2efcd50>,
#  <matplotlib.lines.Line2D at 0x7f79e2efce50>,
#  <matplotlib.lines.Line2D at 0x7f79e2efcf50>,
#  <matplotlib.lines.Line2D at 0x7f79e2efcf90>,
#  <matplotlib.lines.Line2D at 0x7f79e2f06190>,
#  <matplotlib.lines.Line2D at 0x7f79e2f06290>,
#  <matplotlib.lines.Line2D at 0x7f79e2f06390>,
#  <matplotlib.lines.Line2D at 0x7f79e2f06490>,
#  <matplotlib.lines.Line2D at 0x7f79e2f06590>,
#  <matplotlib.lines.Line2D at 0x7f79a28e8450>,
#  <matplotlib.lines.Line2D at 0x7f79e2f06750>,
#  <matplotlib.lines.Line2D at 0x7f79e2f06850>,
#  <matplotlib.lines.Line2D at 0x7f79e2f06950>,
#  <matplotlib.lines.Line2D at 0x7f79e2f06a50>,
#  <matplotlib.lines.Line2D at 0x7f79e2f06b50>,
#  <matplotlib.lines.Line2D at 0x7f79e2f06c50>,
#  <matplotlib.lines.Line2D at 0x7f79e2f06d50>,
#  <matplotlib.lines.Line2D at 0x7f79e2f06e50>,
#  <matplotlib.lines.Line2D at 0x7f79e2f06f50>,
#  <matplotlib.lines.Line2D at 0x7f79e2f06f90>,
#  <matplotlib.lines.Line2D at 0x7f79e2f10190>,
#  <matplotlib.lines.Line2D at 0x7f79e2f10290>,
#  <matplotlib.lines.Line2D at 0x7f79e2f10390>,
#  <matplotlib.lines.Line2D at 0x7f79e2f10490>,
#  <matplotlib.lines.Line2D at 0x7f79e2f10590>,
#  <matplotlib.lines.Line2D at 0x7f79e2f10690>,
#  <matplotlib.lines.Line2D at 0x7f79e2f10790>,
#  <matplotlib.lines.Line2D at 0x7f79e2f10890>,
#  <matplotlib.lines.Line2D at 0x7f79e2f10990>,
#  <matplotlib.lines.Line2D at 0x7f79e2f10a90>,
#  <matplotlib.lines.Line2D at 0x7f79e2f10b90>,
#  <matplotlib.lines.Line2D at 0x7f79e2f10c90>,
#  <matplotlib.lines.Line2D at 0x7f79e2f10d90>,
#  <matplotlib.lines.Line2D at 0x7f79e2f10e90>,
#  <matplotlib.lines.Line2D at 0x7f79e2f10f90>,
#  <matplotlib.lines.Line2D at 0x7f79e2f10fd0>,
#  <matplotlib.lines.Line2D at 0x7f79e2f191d0>,
#  <matplotlib.lines.Line2D at 0x7f79e2f192d0>,
#  <matplotlib.lines.Line2D at 0x7f79e2f193d0>,
#  <matplotlib.lines.Line2D at 0x7f79e2f194d0>,
#  <matplotlib.lines.Line2D at 0x7f79e2f195d0>,
#  <matplotlib.lines.Line2D at 0x7f79e2f196d0>,
#  <matplotlib.lines.Line2D at 0x7f79e2f197d0>,
#  <matplotlib.lines.Line2D at 0x7f79e2f198d0>]
