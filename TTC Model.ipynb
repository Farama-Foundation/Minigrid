# %%
import pandas as pd

# %%
df = pd.read_csv("TTC.csv")

# %%
df
# Out:
#      pedX  pedY  vehX  vehY  TTC
# 0     900    25   764   107    3
# 1     900    53   810   107    2
# 2     900    81   856   107    1
# 3     900    25   653   111    3
# 4     900    54   736   111    2
# ..    ...   ...   ...   ...  ...
# 595   900    49   618    95    2
# 596   900    73   759    95    1
# 597   900   275   289   200    3
# 598   900   250   493   200    2
# 599   900   225   697   200    1
#
# [600 rows x 5 columns]

# %%
df["distAhead"] = (df.pedX - df.vehX)/10 # in meters
df["distLR"] = (df.pedY - df.vehY)/10 # in meters

# %%
df
# Out:
#      pedX  pedY  vehX  vehY  TTC  distAhead  distLR
# 0     900    25   764   107    3       13.6    -8.2
# 1     900    53   810   107    2        9.0    -5.4
# 2     900    81   856   107    1        4.4    -2.6
# 3     900    25   653   111    3       24.7    -8.6
# 4     900    54   736   111    2       16.4    -5.7
# ..    ...   ...   ...   ...  ...        ...     ...
# 595   900    49   618    95    2       28.2    -4.6
# 596   900    73   759    95    1       14.1    -2.2
# 597   900   275   289   200    3       61.1     7.5
# 598   900   250   493   200    2       40.7     5.0
# 599   900   225   697   200    1       20.3     2.5
#
# [600 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

x = df[df.TTC==3]["distAhead"]
y = df[df.TTC==3]["distLR"]
plt.xlim(-20, 100)  # Set the lower and upper limits for the x-axis
plt.ylim(-40, 40)  # Set the lower and upper limits for the y-axis
plt.plot([-20, 100], [0, 0], linestyle='dotted', color='gray')
plt.plot([0, 0], [-40, 40], linestyle='dotted', color='gray')

plt.scatter(x, y)

# %%
x = df[df.TTC==2]["distAhead"]
y = df[df.TTC==2]["distLR"]
plt.xlim(-10, 70)  # Set the lower and upper limits for the x-axis
plt.ylim(-30, 30)  # Set the lower and upper limits for the y-axis
plt.plot([-10, 70], [0, 0], linestyle='dotted', color='gray')
plt.plot([0, 0], [-30, 30], linestyle='dotted', color='gray')

plt.scatter(x, y)

# %%
x = df[df.TTC==1]["distAhead"]
y = df[df.TTC==1]["distLR"]
plt.xlim(-5, 35)  # Set the lower and upper limits for the x-axis
plt.ylim(-15, 15)  # Set the lower and upper limits for the y-axis
plt.plot([-5, 35], [0, 0], linestyle='dotted', color='gray')
plt.plot([0, 0], [-15, 15], linestyle='dotted', color='gray')

plt.scatter(x, y)

# %%
x1 = df[df.TTC==3]["distAhead"]
y1 = df[df.TTC==3]["distLR"]
x2 = df[df.TTC==1]["distAhead"]
y2 = df[df.TTC==1]["distLR"]
# Plot the points
# plt.scatter(x, y)

# Connect the points with lines
plt.plot([x1, x2], [y1, y2], linestyle='-', color='blue')
# Out:
# [<matplotlib.lines.Line2D at 0x7f79d17df050>,
#  <matplotlib.lines.Line2D at 0x7f79d17d3550>,
#  <matplotlib.lines.Line2D at 0x7f79d17df350>,
#  <matplotlib.lines.Line2D at 0x7f79d17df450>,
#  <matplotlib.lines.Line2D at 0x7f79d17df550>,
#  <matplotlib.lines.Line2D at 0x7f79d17df590>,
#  <matplotlib.lines.Line2D at 0x7f79d17df790>,
#  <matplotlib.lines.Line2D at 0x7f79d17df890>,
#  <matplotlib.lines.Line2D at 0x7f79d17df990>,
#  <matplotlib.lines.Line2D at 0x7f79d17df650>,
#  <matplotlib.lines.Line2D at 0x7f79d17dfb50>,
#  <matplotlib.lines.Line2D at 0x7f79d17dfc50>,
#  <matplotlib.lines.Line2D at 0x7f79d17dfd50>,
#  <matplotlib.lines.Line2D at 0x7f79d17dfe50>,
#  <matplotlib.lines.Line2D at 0x7f79d17dff50>,
#  <matplotlib.lines.Line2D at 0x7f79d17dff90>,
#  <matplotlib.lines.Line2D at 0x7f79d17e6190>,
#  <matplotlib.lines.Line2D at 0x7f79d17e6290>,
#  <matplotlib.lines.Line2D at 0x7f79d17e6390>,
#  <matplotlib.lines.Line2D at 0x7f79d17e6490>,
#  <matplotlib.lines.Line2D at 0x7f79d17e6590>,
#  <matplotlib.lines.Line2D at 0x7f79d17e6690>,
#  <matplotlib.lines.Line2D at 0x7f79d17e6790>,
#  <matplotlib.lines.Line2D at 0x7f79d17e6890>,
#  <matplotlib.lines.Line2D at 0x7f79d17e6990>,
#  <matplotlib.lines.Line2D at 0x7f79d17e6a90>,
#  <matplotlib.lines.Line2D at 0x7f79d17e6b90>,
#  <matplotlib.lines.Line2D at 0x7f79d17e6c90>,
#  <matplotlib.lines.Line2D at 0x7f79d17e6d90>,
#  <matplotlib.lines.Line2D at 0x7f79d17e6e90>,
#  <matplotlib.lines.Line2D at 0x7f79d17e6f90>,
#  <matplotlib.lines.Line2D at 0x7f79d17e6fd0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f01d0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f02d0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f03d0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f04d0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f05d0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f06d0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f07d0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f08d0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f09d0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f0ad0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f0bd0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f0cd0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f0dd0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f0ed0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f0fd0>,
#  <matplotlib.lines.Line2D at 0x7f7a11041110>,
#  <matplotlib.lines.Line2D at 0x7f7a11041210>,
#  <matplotlib.lines.Line2D at 0x7f7a11041310>,
#  <matplotlib.lines.Line2D at 0x7f7a11041410>,
#  <matplotlib.lines.Line2D at 0x7f7a11041510>,
#  <matplotlib.lines.Line2D at 0x7f7a11041610>,
#  <matplotlib.lines.Line2D at 0x7f7a11041710>,
#  <matplotlib.lines.Line2D at 0x7f7a11041810>,
#  <matplotlib.lines.Line2D at 0x7f7a11041910>,
#  <matplotlib.lines.Line2D at 0x7f7a11041a10>,
#  <matplotlib.lines.Line2D at 0x7f7a11041b10>,
#  <matplotlib.lines.Line2D at 0x7f7a11041c10>,
#  <matplotlib.lines.Line2D at 0x7f7a11041d10>,
#  <matplotlib.lines.Line2D at 0x7f7a11041e10>,
#  <matplotlib.lines.Line2D at 0x7f7a11041f10>,
#  <matplotlib.lines.Line2D at 0x7f7a11041f50>,
#  <matplotlib.lines.Line2D at 0x7f7a11049150>,
#  <matplotlib.lines.Line2D at 0x7f7a11049250>,
#  <matplotlib.lines.Line2D at 0x7f7a11049350>,
#  <matplotlib.lines.Line2D at 0x7f7a11049450>,
#  <matplotlib.lines.Line2D at 0x7f7a11049550>,
#  <matplotlib.lines.Line2D at 0x7f7a11049650>,
#  <matplotlib.lines.Line2D at 0x7f7a11049750>,
#  <matplotlib.lines.Line2D at 0x7f7a11049850>,
#  <matplotlib.lines.Line2D at 0x7f7a11049950>,
#  <matplotlib.lines.Line2D at 0x7f7a11049a50>,
#  <matplotlib.lines.Line2D at 0x7f7a11049b50>,
#  <matplotlib.lines.Line2D at 0x7f7a11049c50>,
#  <matplotlib.lines.Line2D at 0x7f7a11049d50>,
#  <matplotlib.lines.Line2D at 0x7f7a11049e50>,
#  <matplotlib.lines.Line2D at 0x7f7a11049f50>,
#  <matplotlib.lines.Line2D at 0x7f7a11049f90>,
#  <matplotlib.lines.Line2D at 0x7f7a11052190>,
#  <matplotlib.lines.Line2D at 0x7f7a11052290>,
#  <matplotlib.lines.Line2D at 0x7f7a11052390>,
#  <matplotlib.lines.Line2D at 0x7f7a11052490>,
#  <matplotlib.lines.Line2D at 0x7f7a11052590>,
#  <matplotlib.lines.Line2D at 0x7f7a11052690>,
#  <matplotlib.lines.Line2D at 0x7f7a11052790>,
#  <matplotlib.lines.Line2D at 0x7f7a11052890>,
#  <matplotlib.lines.Line2D at 0x7f7a11052990>,
#  <matplotlib.lines.Line2D at 0x7f7a11052a90>,
#  <matplotlib.lines.Line2D at 0x7f7a11052b90>,
#  <matplotlib.lines.Line2D at 0x7f7a11052c90>,
#  <matplotlib.lines.Line2D at 0x7f7a11052d90>,
#  <matplotlib.lines.Line2D at 0x7f7a11052e90>,
#  <matplotlib.lines.Line2D at 0x7f7a11052f90>,
#  <matplotlib.lines.Line2D at 0x7f7a11052fd0>,
#  <matplotlib.lines.Line2D at 0x7f7a1105c1d0>,
#  <matplotlib.lines.Line2D at 0x7f7a1105c2d0>,
#  <matplotlib.lines.Line2D at 0x7f7a1105c3d0>,
#  <matplotlib.lines.Line2D at 0x7f7a1105c4d0>,
#  <matplotlib.lines.Line2D at 0x7f7a1105c5d0>,
#  <matplotlib.lines.Line2D at 0x7f7a1105c6d0>,
#  <matplotlib.lines.Line2D at 0x7f7a1105c7d0>,
#  <matplotlib.lines.Line2D at 0x7f7a1105c8d0>,
#  <matplotlib.lines.Line2D at 0x7f7a1105c9d0>,
#  <matplotlib.lines.Line2D at 0x7f7a1105cad0>,
#  <matplotlib.lines.Line2D at 0x7f7a1105cbd0>,
#  <matplotlib.lines.Line2D at 0x7f7a1105ccd0>,
#  <matplotlib.lines.Line2D at 0x7f7a1105cdd0>,
#  <matplotlib.lines.Line2D at 0x7f7a1105ced0>,
#  <matplotlib.lines.Line2D at 0x7f7a1105cfd0>,
#  <matplotlib.lines.Line2D at 0x7f7a11065110>,
#  <matplotlib.lines.Line2D at 0x7f7a11065210>,
#  <matplotlib.lines.Line2D at 0x7f7a11065310>,
#  <matplotlib.lines.Line2D at 0x7f7a11065410>,
#  <matplotlib.lines.Line2D at 0x7f7a11065510>,
#  <matplotlib.lines.Line2D at 0x7f7a11065610>,
#  <matplotlib.lines.Line2D at 0x7f7a11065710>,
#  <matplotlib.lines.Line2D at 0x7f7a11065810>,
#  <matplotlib.lines.Line2D at 0x7f7a11065910>,
#  <matplotlib.lines.Line2D at 0x7f7a11065a10>,
#  <matplotlib.lines.Line2D at 0x7f7a11065b10>,
#  <matplotlib.lines.Line2D at 0x7f7a11065c10>,
#  <matplotlib.lines.Line2D at 0x7f7a11065d10>,
#  <matplotlib.lines.Line2D at 0x7f7a11065e10>,
#  <matplotlib.lines.Line2D at 0x7f7a11065f10>,
#  <matplotlib.lines.Line2D at 0x7f7a11065f50>,
#  <matplotlib.lines.Line2D at 0x7f7a1106e150>,
#  <matplotlib.lines.Line2D at 0x7f7a1106e250>,
#  <matplotlib.lines.Line2D at 0x7f7a1106e350>,
#  <matplotlib.lines.Line2D at 0x7f7a1106e450>,
#  <matplotlib.lines.Line2D at 0x7f7a1106e550>,
#  <matplotlib.lines.Line2D at 0x7f7a1106e650>,
#  <matplotlib.lines.Line2D at 0x7f7a1106e750>,
#  <matplotlib.lines.Line2D at 0x7f7a1106e850>,
#  <matplotlib.lines.Line2D at 0x7f7a1106e950>,
#  <matplotlib.lines.Line2D at 0x7f7a1106ea50>,
#  <matplotlib.lines.Line2D at 0x7f7a1106eb50>,
#  <matplotlib.lines.Line2D at 0x7f7a1106ec50>,
#  <matplotlib.lines.Line2D at 0x7f7a1106ed50>,
#  <matplotlib.lines.Line2D at 0x7f7a1106ee50>,
#  <matplotlib.lines.Line2D at 0x7f7a1106ef50>,
#  <matplotlib.lines.Line2D at 0x7f7a1106ef90>,
#  <matplotlib.lines.Line2D at 0x7f7a11076190>,
#  <matplotlib.lines.Line2D at 0x7f7a11076290>,
#  <matplotlib.lines.Line2D at 0x7f7a11076390>,
#  <matplotlib.lines.Line2D at 0x7f7a11076490>,
#  <matplotlib.lines.Line2D at 0x7f7a11076590>,
#  <matplotlib.lines.Line2D at 0x7f7a11076690>,
#  <matplotlib.lines.Line2D at 0x7f7a11076790>,
#  <matplotlib.lines.Line2D at 0x7f7a11076890>,
#  <matplotlib.lines.Line2D at 0x7f7a11076990>,
#  <matplotlib.lines.Line2D at 0x7f7a11076a90>,
#  <matplotlib.lines.Line2D at 0x7f7a11076b90>,
#  <matplotlib.lines.Line2D at 0x7f7a11076c90>,
#  <matplotlib.lines.Line2D at 0x7f7a11076d90>,
#  <matplotlib.lines.Line2D at 0x7f7a11076e90>,
#  <matplotlib.lines.Line2D at 0x7f7a11076f90>,
#  <matplotlib.lines.Line2D at 0x7f7a11076fd0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f81d0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f82d0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f83d0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f84d0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f85d0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f86d0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f87d0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f88d0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f89d0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f8ad0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f8bd0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f8cd0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f8dd0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f8ed0>,
#  <matplotlib.lines.Line2D at 0x7f79d17f8fd0>,
#  <matplotlib.lines.Line2D at 0x7f79d1801110>,
#  <matplotlib.lines.Line2D at 0x7f79d1801210>,
#  <matplotlib.lines.Line2D at 0x7f79d1801310>,
#  <matplotlib.lines.Line2D at 0x7f79d1801410>,
#  <matplotlib.lines.Line2D at 0x7f79d1801510>,
#  <matplotlib.lines.Line2D at 0x7f79d1801610>,
#  <matplotlib.lines.Line2D at 0x7f79d1801710>,
#  <matplotlib.lines.Line2D at 0x7f79d1801810>,
#  <matplotlib.lines.Line2D at 0x7f79d1801910>,
#  <matplotlib.lines.Line2D at 0x7f79d1801a10>,
#  <matplotlib.lines.Line2D at 0x7f79d1801b10>,
#  <matplotlib.lines.Line2D at 0x7f79d1801c10>,
#  <matplotlib.lines.Line2D at 0x7f79d1801d10>,
#  <matplotlib.lines.Line2D at 0x7f79d1801e10>,
#  <matplotlib.lines.Line2D at 0x7f79d1801f10>,
#  <matplotlib.lines.Line2D at 0x7f79d1801f50>,
#  <matplotlib.lines.Line2D at 0x7f79d180a150>,
#  <matplotlib.lines.Line2D at 0x7f79d180a250>,
#  <matplotlib.lines.Line2D at 0x7f79d180a350>,
#  <matplotlib.lines.Line2D at 0x7f79d180a450>,
#  <matplotlib.lines.Line2D at 0x7f79d180a550>,
#  <matplotlib.lines.Line2D at 0x7f79d180a650>,
#  <matplotlib.lines.Line2D at 0x7f79d180a750>,
#  <matplotlib.lines.Line2D at 0x7f79d180a850>,
#  <matplotlib.lines.Line2D at 0x7f79d180a950>,
#  <matplotlib.lines.Line2D at 0x7f79d180aa50>,
#  <matplotlib.lines.Line2D at 0x7f79d180ab50>]
