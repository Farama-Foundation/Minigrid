# %%
import pandas as pd

# %%
df = pd.read_csv("TTC.csv")

# %%
df
# Out:
#      pedX  pedY  vehX  vehY  TTC
# 0     900    25   518   124    3
# 1     900    58   646   124    2
# 2     900    91   774   124    1
# 3     900   275   581   217    3
# 4     900   255   688   217    2
# ..    ...   ...   ...   ...  ...
# 595   900   256   578   220    2
# 596   900   237   740   220    1
# 597   900   275   548   194    3
# 598   900   248   666   194    2
# 599   900   221   784   194    1
#
# [600 rows x 5 columns]

# %%
df["distAhead"] = (df.pedX - df.vehX)/10 # in meters
df["distLR"] = (df.pedY - df.vehY)/10 # in meters

# %%
df
# Out:
#      pedX  pedY  vehX  vehY  TTC  distAhead  distLR
# 0     900    25   518   124    3       38.2    -9.9
# 1     900    58   646   124    2       25.4    -6.6
# 2     900    91   774   124    1       12.6    -3.3
# 3     900   275   581   217    3       31.9     5.8
# 4     900   255   688   217    2       21.2     3.8
# ..    ...   ...   ...   ...  ...        ...     ...
# 595   900   256   578   220    2       32.2     3.6
# 596   900   237   740   220    1       16.0     1.7
# 597   900   275   548   194    3       35.2     8.1
# 598   900   248   666   194    2       23.4     5.4
# 599   900   221   784   194    1       11.6     2.7
#
# [600 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

x = df[df.TTC==3]["distAhead"]
y = df[df.TTC==3]["distLR"]
plt.xlim(-20, 100)  # Set the lower and upper limits for the x-axis
plt.ylim(-40, 40)  # Set the lower and upper limits for the y-axis
plt.plot([-20, 100], [0, 0], linestyle='dotted', color='gray')
plt.plot([0, 0], [-40, 40], linestyle='dotted', color='gray')
plt.xlabel('Behind << >> Ahead (m)')
plt.ylabel('Right << >> Left (m)')
plt.title('Pedestrian: TTC = 3s')

plt.scatter(x, y)

# %%
x = df[df.TTC==2]["distAhead"]
y = df[df.TTC==2]["distLR"]
plt.xlim(-10, 70)  # Set the lower and upper limits for the x-axis
plt.ylim(-30, 30)  # Set the lower and upper limits for the y-axis
plt.plot([-10, 70], [0, 0], linestyle='dotted', color='gray')
plt.plot([0, 0], [-30, 30], linestyle='dotted', color='gray')
plt.xlabel('Behind << >> Ahead (m)')
plt.ylabel('Right << >> Left (m)')
plt.title('Pedestrian: TTC = 2s')

plt.scatter(x, y)

# %%
x = df[df.TTC==1]["distAhead"]
y = df[df.TTC==1]["distLR"]
plt.xlim(-5, 35)  # Set the lower and upper limits for the x-axis
plt.ylim(-15, 15)  # Set the lower and upper limits for the y-axis
plt.plot([-5, 35], [0, 0], linestyle='dotted', color='gray')
plt.plot([0, 0], [-15, 15], linestyle='dotted', color='gray')
plt.xlabel('Behind << >> Ahead (m)')
plt.ylabel('Right << >> Left (m)')
plt.title('Pedestrian: TTC = 1s')

plt.scatter(x, y)

# %%
x1 = df[df.TTC==3]["distAhead"]
y1 = df[df.TTC==3]["distLR"]
x2 = df[df.TTC==1]["distAhead"]
y2 = df[df.TTC==1]["distLR"]
plt.xlim(-20, 100)  # Set the lower and upper limits for the x-axis
plt.ylim(-40, 40)  # Set the lower and upper limits for the y-axis
plt.plot([-20, 100], [0, 0], linestyle='dotted', color='gray')
plt.plot([0, 0], [-40, 40], linestyle='dotted', color='gray')
plt.xlabel('Behind << >> Ahead (m)')
plt.ylabel('Right << >> Left (m)')
plt.title('Pedestrian: TTC = 1-3s')

# Connect the points with lines
plt.plot([x1, x2], [y1, y2], linestyle='-', color='blue')
# Out:
# [<matplotlib.lines.Line2D at 0x7f79b040bc50>,
#  <matplotlib.lines.Line2D at 0x7f79b040be50>,
#  <matplotlib.lines.Line2D at 0x7f79b040bf90>,
#  <matplotlib.lines.Line2D at 0x7f79b040bfd0>,
#  <matplotlib.lines.Line2D at 0x7f79e32501d0>,
#  <matplotlib.lines.Line2D at 0x7f79e3250210>,
#  <matplotlib.lines.Line2D at 0x7f79e3250410>,
#  <matplotlib.lines.Line2D at 0x7f79e3250510>,
#  <matplotlib.lines.Line2D at 0x7f79e3250610>,
#  <matplotlib.lines.Line2D at 0x7f79e32502d0>,
#  <matplotlib.lines.Line2D at 0x7f79e32507d0>,
#  <matplotlib.lines.Line2D at 0x7f79e32508d0>,
#  <matplotlib.lines.Line2D at 0x7f79e32509d0>,
#  <matplotlib.lines.Line2D at 0x7f79e3250ad0>,
#  <matplotlib.lines.Line2D at 0x7f79e3250bd0>,
#  <matplotlib.lines.Line2D at 0x7f79e3250cd0>,
#  <matplotlib.lines.Line2D at 0x7f79e3250dd0>,
#  <matplotlib.lines.Line2D at 0x7f79e3250ed0>,
#  <matplotlib.lines.Line2D at 0x7f79e3250fd0>,
#  <matplotlib.lines.Line2D at 0x7f79e325a110>,
#  <matplotlib.lines.Line2D at 0x7f79e325a210>,
#  <matplotlib.lines.Line2D at 0x7f79e325a310>,
#  <matplotlib.lines.Line2D at 0x7f79e325a410>,
#  <matplotlib.lines.Line2D at 0x7f79e325a510>,
#  <matplotlib.lines.Line2D at 0x7f79e325a610>,
#  <matplotlib.lines.Line2D at 0x7f79e325a710>,
#  <matplotlib.lines.Line2D at 0x7f79e325a810>,
#  <matplotlib.lines.Line2D at 0x7f79e325a910>,
#  <matplotlib.lines.Line2D at 0x7f79e325aa10>,
#  <matplotlib.lines.Line2D at 0x7f79e325ab10>,
#  <matplotlib.lines.Line2D at 0x7f79e325ac10>,
#  <matplotlib.lines.Line2D at 0x7f79e325ad10>,
#  <matplotlib.lines.Line2D at 0x7f79e325ae10>,
#  <matplotlib.lines.Line2D at 0x7f79e325af10>,
#  <matplotlib.lines.Line2D at 0x7f79e325af50>,
#  <matplotlib.lines.Line2D at 0x7f79e3264150>,
#  <matplotlib.lines.Line2D at 0x7f79e3264250>,
#  <matplotlib.lines.Line2D at 0x7f79e3264350>,
#  <matplotlib.lines.Line2D at 0x7f79e3264450>,
#  <matplotlib.lines.Line2D at 0x7f79e3264550>,
#  <matplotlib.lines.Line2D at 0x7f79e3264650>,
#  <matplotlib.lines.Line2D at 0x7f79e3264750>,
#  <matplotlib.lines.Line2D at 0x7f79e3264850>,
#  <matplotlib.lines.Line2D at 0x7f79e3264950>,
#  <matplotlib.lines.Line2D at 0x7f79e3264a50>,
#  <matplotlib.lines.Line2D at 0x7f79e3264b50>,
#  <matplotlib.lines.Line2D at 0x7f79e3264c50>,
#  <matplotlib.lines.Line2D at 0x7f79e3264d50>,
#  <matplotlib.lines.Line2D at 0x7f79e3264e50>,
#  <matplotlib.lines.Line2D at 0x7f79e3264f50>,
#  <matplotlib.lines.Line2D at 0x7f79e3264f90>,
#  <matplotlib.lines.Line2D at 0x7f79e326e190>,
#  <matplotlib.lines.Line2D at 0x7f79e326e290>,
#  <matplotlib.lines.Line2D at 0x7f79e326e390>,
#  <matplotlib.lines.Line2D at 0x7f79e326e490>,
#  <matplotlib.lines.Line2D at 0x7f79e326e590>,
#  <matplotlib.lines.Line2D at 0x7f79e326e690>,
#  <matplotlib.lines.Line2D at 0x7f79e326e790>,
#  <matplotlib.lines.Line2D at 0x7f79e326e890>,
#  <matplotlib.lines.Line2D at 0x7f79e326e990>,
#  <matplotlib.lines.Line2D at 0x7f79e326ea90>,
#  <matplotlib.lines.Line2D at 0x7f79e326eb90>,
#  <matplotlib.lines.Line2D at 0x7f79e326ec90>,
#  <matplotlib.lines.Line2D at 0x7f79e326ed90>,
#  <matplotlib.lines.Line2D at 0x7f79e326ee90>,
#  <matplotlib.lines.Line2D at 0x7f79e326ef90>,
#  <matplotlib.lines.Line2D at 0x7f79e326efd0>,
#  <matplotlib.lines.Line2D at 0x7f79e32771d0>,
#  <matplotlib.lines.Line2D at 0x7f79e32772d0>,
#  <matplotlib.lines.Line2D at 0x7f79e32773d0>,
#  <matplotlib.lines.Line2D at 0x7f79e32774d0>,
#  <matplotlib.lines.Line2D at 0x7f79e32775d0>,
#  <matplotlib.lines.Line2D at 0x7f79e32776d0>,
#  <matplotlib.lines.Line2D at 0x7f79e32777d0>,
#  <matplotlib.lines.Line2D at 0x7f79e32778d0>,
#  <matplotlib.lines.Line2D at 0x7f79e32779d0>,
#  <matplotlib.lines.Line2D at 0x7f79e3277ad0>,
#  <matplotlib.lines.Line2D at 0x7f79e3277bd0>,
#  <matplotlib.lines.Line2D at 0x7f79e3277cd0>,
#  <matplotlib.lines.Line2D at 0x7f79e3277dd0>,
#  <matplotlib.lines.Line2D at 0x7f79e3277ed0>,
#  <matplotlib.lines.Line2D at 0x7f79e3277fd0>,
#  <matplotlib.lines.Line2D at 0x7f79e3282110>,
#  <matplotlib.lines.Line2D at 0x7f79e3282210>,
#  <matplotlib.lines.Line2D at 0x7f79e3282310>,
#  <matplotlib.lines.Line2D at 0x7f79e3282410>,
#  <matplotlib.lines.Line2D at 0x7f79e3282510>,
#  <matplotlib.lines.Line2D at 0x7f79e3282610>,
#  <matplotlib.lines.Line2D at 0x7f79e3282710>,
#  <matplotlib.lines.Line2D at 0x7f79e3282810>,
#  <matplotlib.lines.Line2D at 0x7f79e3282910>,
#  <matplotlib.lines.Line2D at 0x7f79e3282a10>,
#  <matplotlib.lines.Line2D at 0x7f79e3282b10>,
#  <matplotlib.lines.Line2D at 0x7f79e3282c10>,
#  <matplotlib.lines.Line2D at 0x7f79e3282d10>,
#  <matplotlib.lines.Line2D at 0x7f79e3282e10>,
#  <matplotlib.lines.Line2D at 0x7f79e3282f10>,
#  <matplotlib.lines.Line2D at 0x7f79e3282f50>,
#  <matplotlib.lines.Line2D at 0x7f79e328b150>,
#  <matplotlib.lines.Line2D at 0x7f79e328b250>,
#  <matplotlib.lines.Line2D at 0x7f79e328b350>,
#  <matplotlib.lines.Line2D at 0x7f79e328b450>,
#  <matplotlib.lines.Line2D at 0x7f79e328b550>,
#  <matplotlib.lines.Line2D at 0x7f79e328b650>,
#  <matplotlib.lines.Line2D at 0x7f79e328b750>,
#  <matplotlib.lines.Line2D at 0x7f79e328b850>,
#  <matplotlib.lines.Line2D at 0x7f79e328b950>,
#  <matplotlib.lines.Line2D at 0x7f79e328ba50>,
#  <matplotlib.lines.Line2D at 0x7f79e328bb50>,
#  <matplotlib.lines.Line2D at 0x7f79e328bc50>,
#  <matplotlib.lines.Line2D at 0x7f79e328bd50>,
#  <matplotlib.lines.Line2D at 0x7f79e328be50>,
#  <matplotlib.lines.Line2D at 0x7f79e328bf50>,
#  <matplotlib.lines.Line2D at 0x7f79e328bf90>,
#  <matplotlib.lines.Line2D at 0x7f79e3164190>,
#  <matplotlib.lines.Line2D at 0x7f79e3164290>,
#  <matplotlib.lines.Line2D at 0x7f79e3164390>,
#  <matplotlib.lines.Line2D at 0x7f79e3164490>,
#  <matplotlib.lines.Line2D at 0x7f79e3164590>,
#  <matplotlib.lines.Line2D at 0x7f79e3164690>,
#  <matplotlib.lines.Line2D at 0x7f79e3164790>,
#  <matplotlib.lines.Line2D at 0x7f79e3164890>,
#  <matplotlib.lines.Line2D at 0x7f79e3164990>,
#  <matplotlib.lines.Line2D at 0x7f79e3164a90>,
#  <matplotlib.lines.Line2D at 0x7f79e3164b90>,
#  <matplotlib.lines.Line2D at 0x7f79e3164c90>,
#  <matplotlib.lines.Line2D at 0x7f79e3164d90>,
#  <matplotlib.lines.Line2D at 0x7f79e3164e90>,
#  <matplotlib.lines.Line2D at 0x7f79e3164f90>,
#  <matplotlib.lines.Line2D at 0x7f79e3164fd0>,
#  <matplotlib.lines.Line2D at 0x7f79e316e1d0>,
#  <matplotlib.lines.Line2D at 0x7f79e316e2d0>,
#  <matplotlib.lines.Line2D at 0x7f79e316e3d0>,
#  <matplotlib.lines.Line2D at 0x7f79e316e4d0>,
#  <matplotlib.lines.Line2D at 0x7f79e316e5d0>,
#  <matplotlib.lines.Line2D at 0x7f79e316e6d0>,
#  <matplotlib.lines.Line2D at 0x7f79e316e7d0>,
#  <matplotlib.lines.Line2D at 0x7f79e316e8d0>,
#  <matplotlib.lines.Line2D at 0x7f79e316e9d0>,
#  <matplotlib.lines.Line2D at 0x7f79e316ead0>,
#  <matplotlib.lines.Line2D at 0x7f79e316ebd0>,
#  <matplotlib.lines.Line2D at 0x7f79e316ecd0>,
#  <matplotlib.lines.Line2D at 0x7f79e316edd0>,
#  <matplotlib.lines.Line2D at 0x7f79e316eed0>,
#  <matplotlib.lines.Line2D at 0x7f79e316efd0>,
#  <matplotlib.lines.Line2D at 0x7f79e3177110>,
#  <matplotlib.lines.Line2D at 0x7f79e3177210>,
#  <matplotlib.lines.Line2D at 0x7f79e3177310>,
#  <matplotlib.lines.Line2D at 0x7f79e3177410>,
#  <matplotlib.lines.Line2D at 0x7f79e3177510>,
#  <matplotlib.lines.Line2D at 0x7f79e3177610>,
#  <matplotlib.lines.Line2D at 0x7f79e3177710>,
#  <matplotlib.lines.Line2D at 0x7f79e3177810>,
#  <matplotlib.lines.Line2D at 0x7f79e3177910>,
#  <matplotlib.lines.Line2D at 0x7f79e3177a10>,
#  <matplotlib.lines.Line2D at 0x7f79e3177b10>,
#  <matplotlib.lines.Line2D at 0x7f79e3177c10>,
#  <matplotlib.lines.Line2D at 0x7f79e3177d10>,
#  <matplotlib.lines.Line2D at 0x7f79e3177e10>,
#  <matplotlib.lines.Line2D at 0x7f79e3177f10>,
#  <matplotlib.lines.Line2D at 0x7f79e3177f50>,
#  <matplotlib.lines.Line2D at 0x7f79e3182150>,
#  <matplotlib.lines.Line2D at 0x7f79e3182250>,
#  <matplotlib.lines.Line2D at 0x7f79e3182350>,
#  <matplotlib.lines.Line2D at 0x7f79e3182450>,
#  <matplotlib.lines.Line2D at 0x7f79e3182550>,
#  <matplotlib.lines.Line2D at 0x7f79e3182650>,
#  <matplotlib.lines.Line2D at 0x7f79e3182750>,
#  <matplotlib.lines.Line2D at 0x7f79e3182850>,
#  <matplotlib.lines.Line2D at 0x7f79e3182950>,
#  <matplotlib.lines.Line2D at 0x7f79e3182a50>,
#  <matplotlib.lines.Line2D at 0x7f79e3182b50>,
#  <matplotlib.lines.Line2D at 0x7f79e3182c50>,
#  <matplotlib.lines.Line2D at 0x7f79e3182d50>,
#  <matplotlib.lines.Line2D at 0x7f79e3182e50>,
#  <matplotlib.lines.Line2D at 0x7f79e3182f50>,
#  <matplotlib.lines.Line2D at 0x7f79e3182f90>,
#  <matplotlib.lines.Line2D at 0x7f79e318a190>,
#  <matplotlib.lines.Line2D at 0x7f79e318a290>,
#  <matplotlib.lines.Line2D at 0x7f79e318a390>,
#  <matplotlib.lines.Line2D at 0x7f79e318a490>,
#  <matplotlib.lines.Line2D at 0x7f79e318a590>,
#  <matplotlib.lines.Line2D at 0x7f79e318a690>,
#  <matplotlib.lines.Line2D at 0x7f79e318a790>,
#  <matplotlib.lines.Line2D at 0x7f79e318a890>,
#  <matplotlib.lines.Line2D at 0x7f79e318a990>,
#  <matplotlib.lines.Line2D at 0x7f79e318aa90>,
#  <matplotlib.lines.Line2D at 0x7f79e318ab90>,
#  <matplotlib.lines.Line2D at 0x7f79e318ac90>,
#  <matplotlib.lines.Line2D at 0x7f79e318ad90>,
#  <matplotlib.lines.Line2D at 0x7f79e318ae90>,
#  <matplotlib.lines.Line2D at 0x7f79e318af90>,
#  <matplotlib.lines.Line2D at 0x7f79e318afd0>,
#  <matplotlib.lines.Line2D at 0x7f79e31941d0>,
#  <matplotlib.lines.Line2D at 0x7f79e31942d0>,
#  <matplotlib.lines.Line2D at 0x7f79e31943d0>,
#  <matplotlib.lines.Line2D at 0x7f79e31944d0>,
#  <matplotlib.lines.Line2D at 0x7f79e31945d0>,
#  <matplotlib.lines.Line2D at 0x7f79e31946d0>,
#  <matplotlib.lines.Line2D at 0x7f79e31947d0>]
